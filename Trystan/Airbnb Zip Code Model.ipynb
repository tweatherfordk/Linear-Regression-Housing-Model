# %%
import pandas as pd
king_df = pd.read_csv("/Users/weatherford/Documents/Flatiron/Phase_2_Housing_Project/data/king_county_cleaned.csv")
airbnb_df = pd.read_csv("/Users/weatherford/Documents/Flatiron/Phase_2_Housing_Project/data/airbnb_zipcode_price.csv")

# %%
king_df = king_df.drop(columns=['Unnamed: 0'])

# %%
king_df
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  2014-10-13  221900.0         3       1.00         1180
# 1      6414100192  2014-12-09  538000.0         3       2.25         2570
# 2      5631500400  2015-02-25  180000.0         2       1.00          770
# 3      2487200875  2014-12-09  604000.0         4       3.00         1960
# 4      1954400510  2015-02-18  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018  2014-05-21  360000.0         3       2.50         1530
# 21593  6600060120  2015-02-23  400000.0         4       2.50         2310
# 21594  1523300141  2014-06-23  402101.0         2       0.75         1020
# 21595   291310100  2015-01-16  400000.0         3       2.50         1600
# 21596  1523300157  2014-10-15  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  sqft_above  ...  zipcode      lat  \
# 0          5650     1.0           0        1180  ...    98178  47.5112
# 1          7242     2.0           0        2170  ...    98125  47.7210
# 2         10000     1.0           0         770  ...    98028  47.7379
# 3          5000     1.0           0        1050  ...    98136  47.5208
# 4          8080     1.0           0        1680  ...    98074  47.6168
# ...         ...     ...         ...         ...  ...      ...      ...
# 21592      1131     3.0           0        1530  ...    98103  47.6993
# 21593      5813     2.0           0        2310  ...    98146  47.5107
# 21594      1350     2.0           0        1020  ...    98144  47.5944
# 21595      2388     2.0           0        1600  ...    98027  47.5345
# 21596      1076     2.0           0        1020  ...    98144  47.5941
#
#           long  sqft_living15  sqft_lot15  renov_yr_clean  view_ord  \
# 0     -122.257           1340        5650          1955.0       0.0
# 1     -122.319           1690        7639          1991.0       0.0
# 2     -122.233           2720        8062          1933.0       0.0
# 3     -122.393           1360        5000          1965.0       0.0
# 4     -122.045           1800        7503          1987.0       0.0
# ...        ...            ...         ...             ...       ...
# 21592 -122.346           1530        1509          2009.0       0.0
# 21593 -122.362           1830        7200          2014.0       0.0
# 21594 -122.299           1020        2007          2009.0       0.0
# 21595 -122.069           1410        1287          2004.0       0.0
# 21596 -122.299           1020        1357          2008.0       0.0
#
#        condition_ord  grade_ord  age
# 0                2.0        4.0   60
# 1                2.0        4.0   64
# 2                2.0        3.0   82
# 3                4.0        4.0   50
# 4                2.0        5.0   28
# ...              ...        ...  ...
# 21592            2.0        5.0    6
# 21593            2.0        5.0    1
# 21594            2.0        4.0    6
# 21595            2.0        5.0   11
# 21596            2.0        4.0    7
#
# [21597 rows x 23 columns]

# %%
airbnb_df
# Out:
#     zipcode            id   latitude   longitude       price
# 0     98028  5.829030e+17  47.740110 -122.265170  385.000000
# 1     98034  1.959283e+17  47.710533 -122.248450  113.666667
# 2     98040  1.972584e+17  47.556958 -122.249038  290.166667
# 3     98057  1.775044e+07  47.489650 -122.225220  225.000000
# 4     98101  8.319577e+16  47.610936 -122.335671  236.401487
# 5     98102  5.724235e+16  47.630690 -122.321672  208.516129
# 6     98103  7.954605e+16  47.669819 -122.343402  198.239224
# 7     98104  1.105678e+17  47.602775 -122.328581  168.133333
# 8     98105  8.767323e+16  47.663482 -122.309163  159.490000
# 9     98106  6.652046e+16  47.541882 -122.358118  176.106557
# 10    98107  1.198376e+17  47.667910 -122.374809  211.581498
# 11    98108  1.386757e+17  47.549144 -122.307968  155.711538
# 12    98109  1.466462e+17  47.627789 -122.345090  210.720930
# 13    98112  7.860926e+16  47.629479 -122.301355  233.719457
# 14    98115  5.428200e+16  47.683634 -122.304469  169.318386
# 15    98116  7.703663e+16  47.574526 -122.398955  216.022857
# 16    98117  5.230738e+16  47.685103 -122.377835  179.677419
# 17    98118  7.598362e+16  47.543534 -122.277837  171.003484
# 18    98119  6.924101e+16  47.637914 -122.367207  260.294643
# 19    98121  1.112441e+17  47.614837 -122.345863  217.373494
# 20    98122  8.991994e+16  47.610529 -122.309388  208.050691
# 21    98125  1.056035e+17  47.717467 -122.304702  160.104348
# 22    98126  3.922233e+16  47.556849 -122.375475  169.449438
# 23    98133  9.104818e+16  47.720757 -122.345298  139.547826
# 24    98134  3.238220e+07  47.586563 -122.325736  339.000000
# 25    98136  3.963126e+16  47.541617 -122.388208  181.091954
# 26    98144  6.664053e+16  47.585864 -122.303163  194.319728
# 27    98146  5.113193e+16  47.505161 -122.355293  136.758621
# 28    98155  9.860969e+16  47.739865 -122.301011  130.418605
# 29    98168  1.733117e+17  47.500964 -122.310838  155.425926
# 30    98170  5.948903e+17  47.621560 -122.336310  259.000000
# 31    98177  1.115551e+17  47.710898 -122.366177  183.161290
# 32    98178  7.345680e+16  47.500403 -122.243751  170.121951
# 33    98195  2.442922e+07  47.659620 -122.316277  169.000000
# 34    98199  6.788531e+16  47.648094 -122.393581  214.378947

# %%
price_df = pd.merge(king_df, airbnb_df, on='zipcode', how='left')

# %%
price_df['airbnb_avg_price']= price_df['price_y']

# %%
price_df = price_df.drop(['price_y'], axis=1)

# %%
price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21597 entries, 0 to 21596
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_x              21597 non-null  int64
#  1   date              21597 non-null  object
#  2   price_x           21597 non-null  float64
#  3   bedrooms          21597 non-null  int64
#  4   bathrooms         21597 non-null  float64
#  5   sqft_living       21597 non-null  int64
#  6   sqft_lot          21597 non-null  int64
#  7   floors            21597 non-null  float64
#  8   waterfront        21597 non-null  int64
#  9   sqft_above        21597 non-null  int64
#  10  sqft_basement     21597 non-null  float64
#  11  yr_built          21597 non-null  int64
#  12  yr_renovated      21597 non-null  float64
#  13  zipcode           21597 non-null  int64
#  14  lat               21597 non-null  float64
#  15  long              21597 non-null  float64
#  16  sqft_living15     21597 non-null  int64
#  17  sqft_lot15        21597 non-null  int64
#  18  renov_yr_clean    21597 non-null  float64
#  19  view_ord          21597 non-null  float64
#  20  condition_ord     21597 non-null  float64
#  21  grade_ord         21597 non-null  float64
#  22  age               21597 non-null  int64
#  23  id_y              9356 non-null   float64
#  24  latitude          9356 non-null   float64
#  25  longitude         9356 non-null   float64
#  26  airbnb_avg_price  9356 non-null   float64
# dtypes: float64(15), int64(11), object(1)
# memory usage: 4.6+ MB

# %% [markdown]
# Make a copy of the price_df. Because the Airbnb Data only inclduded price information for zip codes wtih Seattle proper and not all of King County, this will be a subset of the King County data for specifically zip codes in Seattle.

# %%
seattle_df = price_df.copy(deep=True)
seattle_df
# Out:
#              id_x        date   price_x  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  2014-10-13  221900.0         3       1.00         1180
# 1      6414100192  2014-12-09  538000.0         3       2.25         2570
# 2      5631500400  2015-02-25  180000.0         2       1.00          770
# 3      2487200875  2014-12-09  604000.0         4       3.00         1960
# 4      1954400510  2015-02-18  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018  2014-05-21  360000.0         3       2.50         1530
# 21593  6600060120  2015-02-23  400000.0         4       2.50         2310
# 21594  1523300141  2014-06-23  402101.0         2       0.75         1020
# 21595   291310100  2015-01-16  400000.0         3       2.50         1600
# 21596  1523300157  2014-10-15  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  sqft_above  ...  sqft_lot15  \
# 0          5650     1.0           0        1180  ...        5650
# 1          7242     2.0           0        2170  ...        7639
# 2         10000     1.0           0         770  ...        8062
# 3          5000     1.0           0        1050  ...        5000
# 4          8080     1.0           0        1680  ...        7503
# ...         ...     ...         ...         ...  ...         ...
# 21592      1131     3.0           0        1530  ...        1509
# 21593      5813     2.0           0        2310  ...        7200
# 21594      1350     2.0           0        1020  ...        2007
# 21595      2388     2.0           0        1600  ...        1287
# 21596      1076     2.0           0        1020  ...        1357
#
#        renov_yr_clean  view_ord  condition_ord  grade_ord  age          id_y  \
# 0              1955.0       0.0            2.0        4.0   60  7.345680e+16
# 1              1991.0       0.0            2.0        4.0   64  1.056035e+17
# 2              1933.0       0.0            2.0        3.0   82  5.829030e+17
# 3              1965.0       0.0            4.0        4.0   50  3.963126e+16
# 4              1987.0       0.0            2.0        5.0   28           NaN
# ...               ...       ...            ...        ...  ...           ...
# 21592          2009.0       0.0            2.0        5.0    6  7.954605e+16
# 21593          2014.0       0.0            2.0        5.0    1  5.113193e+16
# 21594          2009.0       0.0            2.0        4.0    6  6.664053e+16
# 21595          2004.0       0.0            2.0        5.0   11           NaN
# 21596          2008.0       0.0            2.0        4.0    7  6.664053e+16
#
#         latitude   longitude  airbnb_avg_price
# 0      47.500403 -122.243751        170.121951
# 1      47.717467 -122.304702        160.104348
# 2      47.740110 -122.265170        385.000000
# 3      47.541617 -122.388208        181.091954
# 4            NaN         NaN               NaN
# ...          ...         ...               ...
# 21592  47.669819 -122.343402        198.239224
# 21593  47.505161 -122.355293        136.758621
# 21594  47.585864 -122.303163        194.319728
# 21595        NaN         NaN               NaN
# 21596  47.585864 -122.303163        194.319728
#
# [21597 rows x 27 columns]

# %%
seattle_df.dropna(inplace = True)
seattle_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9356 entries, 0 to 21596
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_x              9356 non-null   int64
#  1   date              9356 non-null   object
#  2   price_x           9356 non-null   float64
#  3   bedrooms          9356 non-null   int64
#  4   bathrooms         9356 non-null   float64
#  5   sqft_living       9356 non-null   int64
#  6   sqft_lot          9356 non-null   int64
#  7   floors            9356 non-null   float64
#  8   waterfront        9356 non-null   int64
#  9   sqft_above        9356 non-null   int64
#  10  sqft_basement     9356 non-null   float64
#  11  yr_built          9356 non-null   int64
#  12  yr_renovated      9356 non-null   float64
#  13  zipcode           9356 non-null   int64
#  14  lat               9356 non-null   float64
#  15  long              9356 non-null   float64
#  16  sqft_living15     9356 non-null   int64
#  17  sqft_lot15        9356 non-null   int64
#  18  renov_yr_clean    9356 non-null   float64
#  19  view_ord          9356 non-null   float64
#  20  condition_ord     9356 non-null   float64
#  21  grade_ord         9356 non-null   float64
#  22  age               9356 non-null   int64
#  23  id_y              9356 non-null   float64
#  24  latitude          9356 non-null   float64
#  25  longitude         9356 non-null   float64
#  26  airbnb_avg_price  9356 non-null   float64
# dtypes: float64(15), int64(11), object(1)
# memory usage: 2.0+ MB

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from   sklearn.linear_model import LinearRegression
from   sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
import warnings

# %matplotlib inline
plt.rcParams['figure.figsize'] = (8.0, 6.0)
plt.style.use('seaborn-poster')

warnings.filterwarnings('ignore')

# %%
X, y = seattle_df[['airbnb_avg_price']] , seattle_df[['price_x']]

# Generate train/test sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=.3, random_state=42
)

# Init, fit, score
multi_model = LinearRegression()
multi_model.fit(X_train, y_train)

print(f"Training score: {multi_model.score(X_train, y_train)}")
multi_model_score = multi_model.score(X_test, y_test)
print(f"Test score: {multi_model.score(X_test, y_test)}")
# Out:
# Training score: 0.0721036386308268
# Test score: 0.0704449507926368

# %%
plt.scatter(seattle_df.airbnb_avg_price, seattle_df.price_x, alpha=0.3)
plt.title("Airbnb Average Price by Zipcode ~ Property Price")
plt.xlabel("Airbnb Average Price by Zipcode")
plt.ylabel("Sale Price")
plt.tight_layout()
plt.show()

# %%
seattle_df.columns
features = seattle_df[['bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'sqft_above', 'sqft_basement',
       'yr_built', 'zipcode', 'lat', 'long', 'sqft_living15',
       'sqft_lot15', 'renov_yr_clean', 'view_ord', 'condition_ord',
       'grade_ord', 'age', 'latitude', 'longitude',
       'airbnb_avg_price']]

# %%
X, y = features, seattle_df[['price_x']]

# Generate train/test sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=.3, random_state=42
)

# Init, fit, score
multi_model = LinearRegression()
multi_model.fit(X_train, y_train)

print(f"Training score: {multi_model.score(X_train, y_train)}")
multi_model_score = multi_model.score(X_test, y_test)
print(f"Test score: {multi_model.score(X_test, y_test)}")
# Out:
# Training score: 0.7507768326583176
# Test score: 0.7583539284720769

# %%
seattle_df.corr()
# Out:
#                       id_x   price_x  bedrooms  bathrooms  sqft_living  \
# id_x              1.000000 -0.013177 -0.002600  -0.016746    -0.019791
# price_x          -0.013177  1.000000  0.331185   0.535845     0.749595
# bedrooms         -0.002600  0.331185  1.000000   0.498095     0.594166
# bathrooms        -0.016746  0.535845  0.498095   1.000000     0.713849
# sqft_living      -0.019791  0.749595  0.594166   0.713849     1.000000
# sqft_lot         -0.057074  0.203175  0.164451   0.068135     0.289683
# floors           -0.009814  0.257486  0.111948   0.463446     0.240187
# waterfront        0.028325  0.299409  0.033824   0.086986     0.149267
# sqft_above       -0.022893  0.699716  0.500846   0.637718     0.852736
# sqft_basement    -0.004128  0.383032  0.379410   0.402878     0.624427
# yr_built         -0.036705 -0.010801  0.040483   0.413886     0.122555
# yr_renovated      0.002374  0.145810  0.066465   0.120923     0.134405
# zipcode          -0.031473 -0.130372 -0.095587  -0.139697    -0.119797
# lat               0.014979  0.065906  0.052748   0.063805     0.054138
# long              0.019424  0.033899  0.156200   0.096459     0.154385
# sqft_living15    -0.037183  0.657873  0.343009   0.450240     0.676249
# sqft_lot15       -0.053073  0.205430  0.165692   0.069238     0.308839
# renov_yr_clean   -0.032353  0.048912  0.067682   0.459809     0.173573
# view_ord          0.011692  0.456273  0.117307   0.239613     0.377754
# condition_ord     0.005695  0.159717  0.102266   0.017903     0.119966
# grade_ord        -0.014497  0.708411  0.321130   0.633019     0.695338
# age               0.036705  0.010801 -0.040483  -0.413886    -0.122555
# id_y             -0.041868 -0.012806  0.096186   0.088251     0.117128
# latitude          0.019561  0.071613  0.044537   0.057639     0.046331
# longitude         0.016270  0.003472  0.140357   0.068044     0.127002
# airbnb_avg_price -0.022200  0.267600  0.066303   0.167427     0.192034
#
#                   sqft_lot    floors  waterfront  sqft_above  sqft_basement  \
# id_x             -0.057074 -0.009814    0.028325   -0.022893      -0.004128
# price_x           0.203175  0.257486    0.299409    0.699716       0.383032
# bedrooms          0.164451  0.111948    0.033824    0.500846       0.379410
# bathrooms         0.068135  0.463446    0.086986    0.637718       0.402878
# sqft_living       0.289683  0.240187    0.149267    0.852736       0.624427
# sqft_lot          1.000000 -0.223591    0.177137    0.270382       0.143597
# floors           -0.223591  1.000000    0.018924    0.433072      -0.181457
# waterfront        0.177137  0.018924    1.000000    0.138565       0.076576
# sqft_above        0.270382  0.433072    0.138565    1.000000       0.136408
# sqft_basement     0.143597 -0.181457    0.076576    0.136408       1.000000
# yr_built         -0.057304  0.469213   -0.000945    0.190227      -0.046713
# yr_renovated      0.028311  0.039492    0.043087    0.118039       0.080112
# zipcode          -0.080407 -0.070646   -0.007012   -0.158873       0.009555
# lat               0.061278  0.028686   -0.031558    0.078600      -0.014099
# long              0.232091 -0.080729    0.052391    0.175986       0.034711
# sqft_living15     0.321899  0.089884    0.161184    0.600928       0.389146
# sqft_lot15        0.669066 -0.278521    0.205076    0.286062       0.154692
# renov_yr_clean   -0.056941  0.480974    0.008740    0.230348      -0.009919
# view_ord          0.191819  0.052556    0.338841    0.297910       0.270954
# condition_ord     0.045679 -0.160900    0.008614    0.016193       0.198683
# grade_ord         0.130333  0.466529    0.118013    0.700918       0.278342
# age               0.057304 -0.469213    0.000945   -0.190227       0.046713
# id_y              0.255015 -0.038201    0.008530    0.152158      -0.005532
# latitude          0.045443  0.037943   -0.034075    0.073051      -0.020645
# longitude         0.224445 -0.082742    0.053658    0.149465       0.021456
# airbnb_avg_price  0.021896  0.148941    0.001891    0.189225       0.078798
#
#                   ...  sqft_lot15  renov_yr_clean  view_ord  condition_ord  \
# id_x              ...   -0.053073       -0.032353  0.011692       0.005695
# price_x           ...    0.205430        0.048912  0.456273       0.159717
# bedrooms          ...    0.165692        0.067682  0.117307       0.102266
# bathrooms         ...    0.069238        0.459809  0.239613       0.017903
# sqft_living       ...    0.308839        0.173573  0.377754       0.119966
# sqft_lot          ...    0.669066       -0.056941  0.191819       0.045679
# floors            ...   -0.278521        0.480974  0.052556      -0.160900
# waterfront        ...    0.205076        0.008740  0.338841       0.008614
# sqft_above        ...    0.286062        0.230348  0.297910       0.016193
# sqft_basement     ...    0.154692       -0.009919  0.270954       0.198683
# yr_built          ...   -0.043900        0.898646 -0.012731      -0.327523
# yr_renovated      ...    0.032789        0.254979  0.094602      -0.083892
# zipcode           ...   -0.069055       -0.122290  0.046989      -0.013832
# lat               ...    0.083570        0.066954 -0.066988       0.043204
# long              ...    0.278830        0.100021 -0.035698      -0.014188
# sqft_living15     ...    0.407906        0.064694  0.452702       0.105738
# sqft_lot15        ...    1.000000       -0.045642  0.234315       0.074817
# renov_yr_clean    ...   -0.045642        1.000000  0.019258      -0.362124
# view_ord          ...    0.234315        0.019258  1.000000       0.041073
# condition_ord     ...    0.074817       -0.362124  0.041073       1.000000
# grade_ord         ...    0.142156        0.398866  0.350518      -0.018344
# age               ...    0.043900       -0.898646  0.012731       0.327523
# id_y              ...    0.297083        0.151198 -0.026521      -0.029160
# latitude          ...    0.060844        0.055928 -0.073605       0.045145
# longitude         ...    0.276083        0.080690 -0.040606      -0.017981
# airbnb_avg_price  ...    0.019355        0.045718  0.067800       0.020630
#
#                   grade_ord       age      id_y  latitude  longitude  \
# id_x              -0.014497  0.036705 -0.041868  0.019561   0.016270
# price_x            0.708411  0.010801 -0.012806  0.071613   0.003472
# bedrooms           0.321130 -0.040483  0.096186  0.044537   0.140357
# bathrooms          0.633019 -0.413886  0.088251  0.057639   0.068044
# sqft_living        0.695338 -0.122555  0.117128  0.046331   0.127002
# sqft_lot           0.130333  0.057304  0.255015  0.045443   0.224445
# floors             0.466529 -0.469213 -0.038201  0.037943  -0.082742
# waterfront         0.118013  0.000945  0.008530 -0.034075   0.053658
# sqft_above         0.700918 -0.190227  0.152158  0.073051   0.149465
# sqft_basement      0.278342  0.046713 -0.005532 -0.020645   0.021456
# yr_built           0.368124 -1.000000  0.175163  0.072611   0.101906
# yr_renovated       0.089041  0.165665 -0.042168 -0.035880  -0.033910
# zipcode           -0.143494  0.136300 -0.576319 -0.232948  -0.450392
# lat                0.105185 -0.083240  0.293438  0.985262   0.066179
# long               0.056966 -0.120677  0.483243  0.087345   0.957249
# sqft_living15      0.596670 -0.043491  0.210451  0.076425   0.213547
# sqft_lot15         0.142156  0.043900  0.297083  0.060844   0.276083
# renov_yr_clean     0.398866 -0.898646  0.151198  0.055928   0.080690
# view_ord           0.350518  0.012731 -0.026521 -0.073605  -0.040606
# condition_ord     -0.018344  0.327523 -0.029160  0.045145  -0.017981
# grade_ord          1.000000 -0.368124  0.078410  0.102692   0.030409
# age               -0.368124  1.000000 -0.175163 -0.072611  -0.101906
# id_y               0.078410 -0.175163  1.000000  0.282753   0.452531
# latitude           0.102692 -0.072611  0.282753  1.000000   0.054482
# longitude          0.030409 -0.101906  0.452531  0.054482   1.000000
# airbnb_avg_price   0.255476 -0.028107  0.588566 -0.012746   0.008502
#
#                   airbnb_avg_price
# id_x                     -0.022200
# price_x                   0.267600
# bedrooms                  0.066303
# bathrooms                 0.167427
# sqft_living               0.192034
# sqft_lot                  0.021896
# floors                    0.148941
# waterfront                0.001891
# sqft_above                0.189225
# sqft_basement             0.078798
# yr_built                  0.028107
# yr_renovated              0.037587
# zipcode                  -0.315907
# lat                      -0.008260
# long                      0.014011
# sqft_living15             0.267689
# sqft_lot15                0.019355
# renov_yr_clean            0.045718
# view_ord                  0.067800
# condition_ord             0.020630
# grade_ord                 0.255476
# age                      -0.028107
# id_y                      0.588566
# latitude                 -0.012746
# longitude                 0.008502
# airbnb_avg_price          1.000000
#
# [26 rows x 26 columns]

# %% [markdown]
# Interaction Model

# %%
y = seattle_df['price_x']
X = seattle_df[['bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'sqft_above', 'sqft_basement',
       'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15',
       'sqft_lot15', 'renov_yr_clean', 'view_ord', 'condition_ord',
       'grade_ord', 'age', 'latitude', 'longitude',
       'airbnb_avg_price']]

linear_withinteraction = PolynomialFeatures(degree = 2, interaction_only = True, include_bias = False)


X_transformed = linear_withinteraction.fit_transform(X)
feat_names = pd.Series(linear_withinteraction.get_feature_names())
feat_names
# Out:
# 0           x0
# 1           x1
# 2           x2
# 3           x3
# 4           x4
#         ...
# 271    x19 x21
# 272    x19 x22
# 273    x20 x21
# 274    x20 x22
# 275    x21 x22
# Length: 276, dtype: object

# %%
xs = ['x0', 'x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9', 'x10',  'x11', 'x12', 'x13', 'x14', 'x15','x16','x17','x18','x19','x20','x21','x22']

columns = X.columns

map_dict = {x:y for x,y in zip(xs, columns)}

for key, value in map_dict.items():
    feat_names = feat_names.str.replace(key, value)


X_trans_df = pd.DataFrame(X_transformed)
X_trans_df.columns = feat_names

X_trans_df.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  sqft_above  \
# 0       3.0       1.00       1180.0    5650.0     1.0         0.0      1180.0
# 1       3.0       2.25       2570.0    7242.0     2.0         0.0      2170.0
# 2       2.0       1.00        770.0   10000.0     1.0         0.0       770.0
# 3       4.0       3.00       1960.0    5000.0     1.0         0.0      1050.0
# 4       3.0       1.00       1780.0    7470.0     1.0         0.0      1050.0
#
#    sqft_basement  yr_built  yr_renovated  ...  bathrooms8 bathrooms9  \
# 0            0.0    1955.0           0.0  ...                  240.0
# 1          400.0    1951.0        1991.0  ...                  256.0
# 2            0.0    1933.0           0.0  ...                  246.0
# 3          910.0    1965.0           0.0  ...                  200.0
# 4          730.0    1960.0           0.0  ...                  220.0
#
#    bathrooms8 sqft_living0  bathrooms8 sqft_living1  bathrooms8 sqft_living2  \
# 0               190.001613              -488.975005               680.487805
# 1               190.869868              -489.218809               640.417391
# 2               143.220330              -366.795510              1155.000000
# 3               190.166468              -489.552831               724.367816
# 4               190.020645              -489.421173               547.034483
#
#    bathrooms9 sqft_living0  bathrooms9 sqft_living1  bathrooms9 sqft_living2  \
# 0              2850.024188             -7334.625075             10207.317073
# 1              3053.917882             -7827.500951             10246.678261
# 2              3914.689020            -10025.743940             31570.000000
# 3              2377.080848             -6119.410381              9054.597701
# 4              2612.783871             -6729.541128              7521.724138
#
#    sqft_living0 sqft_living1  sqft_living0 sqft_living2  \
# 0               -5806.627465                8080.861265
# 1               -5836.070588                7639.773919
# 2               -5836.952665               18379.942350
# 3               -5818.533287                8609.404312
# 4               -5812.507940                6496.740333
#
#    sqft_living1 sqft_living2
# 0              -20796.345487
# 1              -19581.514609
# 2              -47072.090450
# 3              -22163.519669
# 4              -16733.141138
#
# [5 rows x 276 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_trans_df, y, test_size=.3, random_state=42
)


# Init, fit, score
stand_model = LinearRegression()
stand_model.fit(X_train, y_train)

print(f"Training score: {stand_model.score(X_train, y_train)}")

print(f"Testing score: {stand_model.score(X_test, y_test)}")

stand_model_score  = stand_model.score(X_test, y_test)
# Out:
# Training score: 0.8812310514700116
# Testing score: 0.8226577636584166
