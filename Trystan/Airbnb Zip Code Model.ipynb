# %%
import pandas as pd
king_df = pd.read_csv("/Users/weatherford/Documents/Flatiron/Phase_2_Housing_Project/data/king_county_cleaned.csv")
airbnb_df = pd.read_csv("/Users/weatherford/Documents/Flatiron/Phase_2_Housing_Project/data/airbnb_zipcode_price.csv")

# %%
king_df = king_df.drop(columns=['Unnamed: 0'])

# %%
king_df
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  2014-10-13  221900.0         3       1.00         1180
# 1      6414100192  2014-12-09  538000.0         3       2.25         2570
# 2      5631500400  2015-02-25  180000.0         2       1.00          770
# 3      2487200875  2014-12-09  604000.0         4       3.00         1960
# 4      1954400510  2015-02-18  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018  2014-05-21  360000.0         3       2.50         1530
# 21593  6600060120  2015-02-23  400000.0         4       2.50         2310
# 21594  1523300141  2014-06-23  402101.0         2       0.75         1020
# 21595   291310100  2015-01-16  400000.0         3       2.50         1600
# 21596  1523300157  2014-10-15  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  sqft_above  ...  zipcode      lat  \
# 0          5650     1.0           0        1180  ...    98178  47.5112
# 1          7242     2.0           0        2170  ...    98125  47.7210
# 2         10000     1.0           0         770  ...    98028  47.7379
# 3          5000     1.0           0        1050  ...    98136  47.5208
# 4          8080     1.0           0        1680  ...    98074  47.6168
# ...         ...     ...         ...         ...  ...      ...      ...
# 21592      1131     3.0           0        1530  ...    98103  47.6993
# 21593      5813     2.0           0        2310  ...    98146  47.5107
# 21594      1350     2.0           0        1020  ...    98144  47.5944
# 21595      2388     2.0           0        1600  ...    98027  47.5345
# 21596      1076     2.0           0        1020  ...    98144  47.5941
#
#           long  sqft_living15  sqft_lot15  renov_yr_clean  view_ord  \
# 0     -122.257           1340        5650          1955.0       0.0
# 1     -122.319           1690        7639          1991.0       0.0
# 2     -122.233           2720        8062          1933.0       0.0
# 3     -122.393           1360        5000          1965.0       0.0
# 4     -122.045           1800        7503          1987.0       0.0
# ...        ...            ...         ...             ...       ...
# 21592 -122.346           1530        1509          2009.0       0.0
# 21593 -122.362           1830        7200          2014.0       0.0
# 21594 -122.299           1020        2007          2009.0       0.0
# 21595 -122.069           1410        1287          2004.0       0.0
# 21596 -122.299           1020        1357          2008.0       0.0
#
#        condition_ord  grade_ord  age
# 0                2.0        4.0   60
# 1                2.0        4.0   64
# 2                2.0        3.0   82
# 3                4.0        4.0   50
# 4                2.0        5.0   28
# ...              ...        ...  ...
# 21592            2.0        5.0    6
# 21593            2.0        5.0    1
# 21594            2.0        4.0    6
# 21595            2.0        5.0   11
# 21596            2.0        4.0    7
#
# [21597 rows x 23 columns]

# %%
airbnb_df
# Out:
#     zipcode            id   latitude   longitude       price
# 0     98028  5.829030e+17  47.740110 -122.265170  385.000000
# 1     98034  1.959283e+17  47.710533 -122.248450  113.666667
# 2     98040  1.972584e+17  47.556958 -122.249038  290.166667
# 3     98057  1.775044e+07  47.489650 -122.225220  225.000000
# 4     98101  8.319577e+16  47.610936 -122.335671  236.401487
# 5     98102  5.724235e+16  47.630690 -122.321672  208.516129
# 6     98103  7.954605e+16  47.669819 -122.343402  198.239224
# 7     98104  1.105678e+17  47.602775 -122.328581  168.133333
# 8     98105  8.767323e+16  47.663482 -122.309163  159.490000
# 9     98106  6.652046e+16  47.541882 -122.358118  176.106557
# 10    98107  1.198376e+17  47.667910 -122.374809  211.581498
# 11    98108  1.386757e+17  47.549144 -122.307968  155.711538
# 12    98109  1.466462e+17  47.627789 -122.345090  210.720930
# 13    98112  7.860926e+16  47.629479 -122.301355  233.719457
# 14    98115  5.428200e+16  47.683634 -122.304469  169.318386
# 15    98116  7.703663e+16  47.574526 -122.398955  216.022857
# 16    98117  5.230738e+16  47.685103 -122.377835  179.677419
# 17    98118  7.598362e+16  47.543534 -122.277837  171.003484
# 18    98119  6.924101e+16  47.637914 -122.367207  260.294643
# 19    98121  1.112441e+17  47.614837 -122.345863  217.373494
# 20    98122  8.991994e+16  47.610529 -122.309388  208.050691
# 21    98125  1.056035e+17  47.717467 -122.304702  160.104348
# 22    98126  3.922233e+16  47.556849 -122.375475  169.449438
# 23    98133  9.104818e+16  47.720757 -122.345298  139.547826
# 24    98134  3.238220e+07  47.586563 -122.325736  339.000000
# 25    98136  3.963126e+16  47.541617 -122.388208  181.091954
# 26    98144  6.664053e+16  47.585864 -122.303163  194.319728
# 27    98146  5.113193e+16  47.505161 -122.355293  136.758621
# 28    98155  9.860969e+16  47.739865 -122.301011  130.418605
# 29    98168  1.733117e+17  47.500964 -122.310838  155.425926
# 30    98170  5.948903e+17  47.621560 -122.336310  259.000000
# 31    98177  1.115551e+17  47.710898 -122.366177  183.161290
# 32    98178  7.345680e+16  47.500403 -122.243751  170.121951
# 33    98195  2.442922e+07  47.659620 -122.316277  169.000000
# 34    98199  6.788531e+16  47.648094 -122.393581  214.378947

# %%
price_df = pd.merge(king_df, airbnb_df, on='zipcode', how='inner')

# %% [markdown]
# All zip codes in seattle_df are within the zip_price dataframe:

# %%
set((price_df['zipcode'].unique())).issubset(set(airbnb_df['zipcode'].unique()))
# Out:
# True

# %%
price_df['airbnb_avg_price']= price_df['price_y']
price_df['house_price']= price_df['price_x']

# %%
price_df = price_df.drop(['price_y'], axis=1)
price_df = price_df.drop(['price_x'], axis=1)

# %%
len(price_df['zipcode'].unique())
# Out:
# 28

# %%
price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9356 entries, 0 to 9355
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_x              9356 non-null   int64
#  1   date              9356 non-null   object
#  2   bedrooms          9356 non-null   int64
#  3   bathrooms         9356 non-null   float64
#  4   sqft_living       9356 non-null   int64
#  5   sqft_lot          9356 non-null   int64
#  6   floors            9356 non-null   float64
#  7   waterfront        9356 non-null   int64
#  8   sqft_above        9356 non-null   int64
#  9   sqft_basement     9356 non-null   float64
#  10  yr_built          9356 non-null   int64
#  11  yr_renovated      9356 non-null   float64
#  12  zipcode           9356 non-null   int64
#  13  lat               9356 non-null   float64
#  14  long              9356 non-null   float64
#  15  sqft_living15     9356 non-null   int64
#  16  sqft_lot15        9356 non-null   int64
#  17  renov_yr_clean    9356 non-null   float64
#  18  view_ord          9356 non-null   float64
#  19  condition_ord     9356 non-null   float64
#  20  grade_ord         9356 non-null   float64
#  21  age               9356 non-null   int64
#  22  id_y              9356 non-null   float64
#  23  latitude          9356 non-null   float64
#  24  longitude         9356 non-null   float64
#  25  airbnb_avg_price  9356 non-null   float64
#  26  house_price       9356 non-null   float64
# dtypes: float64(15), int64(11), object(1)
# memory usage: 2.0+ MB

# %% [markdown]
# Make a copy of the price_df. Because the Airbnb Data only inclduded price information for zip codes wtih Seattle proper and not all of King County, this will be a subset of the King County data for specifically zip codes in Seattle.

# %%
seattle_df = price_df.copy(deep=True)
seattle_df
# Out:
#             id_x        date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0     7129300520  2014-10-13         3       1.00         1180      5650
# 1     4060000240  2014-06-23         2       1.00          880      6780
# 2     4058801670  2014-07-17         3       2.25         2100      8201
# 3     2976800796  2014-09-25         3       1.00         1300      5898
# 4     6874200960  2015-02-27         2       1.00          860      5265
# ...          ...         ...       ...        ...          ...       ...
# 9351  2895800590  2014-10-20         5       2.50         2170      2752
# 9352  3438503021  2014-11-05         3       2.50         2430      7049
# 9353   880000205  2014-07-29         3       2.00         1260      1125
# 9354  3438501329  2014-05-20         2       2.50         1590      2656
# 9355  3438501862  2014-05-13         3       2.50         1450      5008
#
#       floors  waterfront  sqft_above  sqft_basement  ...  renov_yr_clean  \
# 0        1.0           0        1180            0.0  ...          1955.0
# 1        1.0           0         880            0.0  ...          1945.0
# 2        1.0           0        1620          480.0  ...          1967.0
# 3        1.0           0        1300            0.0  ...          1961.0
# 4        1.0           0         860            0.0  ...          1931.0
# ...      ...         ...         ...            ...  ...             ...
# 9351     2.0           0        2170            0.0  ...          2014.0
# 9352     2.0           0        2430            0.0  ...          2007.0
# 9353     2.0           0         810          450.0  ...          2011.0
# 9354     2.0           0        1220          370.0  ...          2009.0
# 9355     1.0           0         840          610.0  ...          2007.0
#
#       view_ord  condition_ord  grade_ord  age          id_y   latitude  \
# 0          0.0            2.0        4.0   60  7.345680e+16  47.500403
# 1          0.0            3.0        3.0   70  7.345680e+16  47.500403
# 2          2.0            2.0        5.0   48  7.345680e+16  47.500403
# 3          0.0            2.0        4.0   54  7.345680e+16  47.500403
# 4          0.0            2.0        3.0   84  7.345680e+16  47.500403
# ...        ...            ...        ...  ...           ...        ...
# 9351       0.0            2.0        5.0    1  6.652046e+16  47.541882
# 9352       0.0            2.0        5.0    8  6.652046e+16  47.541882
# 9353       0.0            2.0        4.0    4  6.652046e+16  47.541882
# 9354       0.0            2.0        4.0    6  6.652046e+16  47.541882
# 9355       0.0            2.0        4.0    8  6.652046e+16  47.541882
#
#        longitude  airbnb_avg_price  house_price
# 0    -122.243751        170.121951     221900.0
# 1    -122.243751        170.121951     205425.0
# 2    -122.243751        170.121951     445000.0
# 3    -122.243751        170.121951     236000.0
# 4    -122.243751        170.121951     170000.0
# ...          ...               ...          ...
# 9351 -122.358118        176.106557     359800.0
# 9352 -122.358118        176.106557     443000.0
# 9353 -122.358118        176.106557     249000.0
# 9354 -122.358118        176.106557     305000.0
# 9355 -122.358118        176.106557     330000.0
#
# [9356 rows x 27 columns]

# %%
seattle_df.dropna(inplace = True)
print(seattle_df.info())
print(len(seattle_df['zipcode'].unique()))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9356 entries, 0 to 9355
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_x              9356 non-null   int64
#  1   date              9356 non-null   object
#  2   bedrooms          9356 non-null   int64
#  3   bathrooms         9356 non-null   float64
#  4   sqft_living       9356 non-null   int64
#  5   sqft_lot          9356 non-null   int64
#  6   floors            9356 non-null   float64
#  7   waterfront        9356 non-null   int64
#  8   sqft_above        9356 non-null   int64
#  9   sqft_basement     9356 non-null   float64
#  10  yr_built          9356 non-null   int64
#  11  yr_renovated      9356 non-null   float64
#  12  zipcode           9356 non-null   int64
#  13  lat               9356 non-null   float64
#  14  long              9356 non-null   float64
#  15  sqft_living15     9356 non-null   int64
#  16  sqft_lot15        9356 non-null   int64
#  17  renov_yr_clean    9356 non-null   float64
#  18  view_ord          9356 non-null   float64
#  19  condition_ord     9356 non-null   float64
#  20  grade_ord         9356 non-null   float64
#  21  age               9356 non-null   int64
#  22  id_y              9356 non-null   float64
#  23  latitude          9356 non-null   float64
#  24  longitude         9356 non-null   float64
#  25  airbnb_avg_price  9356 non-null   float64
#  26  house_price       9356 non-null   float64
# dtypes: float64(15), int64(11), object(1)
# memory usage: 2.0+ MB
# None
# 28

# %%
len(seattle_df['zipcode'].unique())
# Out:
# 28

# %%
seattle_df.to_csv('seattle.csv')

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from   sklearn.linear_model import LinearRegression
from   sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
import warnings

# %matplotlib inline
plt.rcParams['figure.figsize'] = (8.0, 6.0)
plt.style.use('seaborn-poster')

warnings.filterwarnings('ignore')

# %%
X, y = seattle_df[['airbnb_avg_price']] , seattle_df[['price_x']]

# Generate train/test sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=.3, random_state=42
)

# Init, fit, score
multi_model = LinearRegression()
multi_model.fit(X_train, y_train)

print(f"Training score: {multi_model.score(X_train, y_train)}")
multi_model_score = multi_model.score(X_test, y_test)
print(f"Test score: {multi_model.score(X_test, y_test)}")
# Out:
# Training score: 0.07400338094928838
# Test score: 0.06488256469329012

# %%
plt.scatter(seattle_df.airbnb_avg_price, seattle_df.price_x, alpha=0.3)
plt.title("Airbnb Average Price by Zipcode ~ Property Price")
plt.xlabel("Airbnb Average Price by Zipcode")
plt.ylabel("Sale Price")
plt.tight_layout()
plt.show()

# %%
seattle_df.columns
features = seattle_df[['bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'sqft_above', 'sqft_basement',
       'yr_built', 'zipcode', 'lat', 'long', 'sqft_living15',
       'sqft_lot15', 'renov_yr_clean', 'view_ord', 'condition_ord',
       'grade_ord', 'age', 'latitude', 'longitude',
       'airbnb_avg_price']]

# %%
X, y = features, seattle_df[['price_x']]

# Generate train/test sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=.3, random_state=42
)

# Init, fit, score
multi_model = LinearRegression()
multi_model.fit(X_train, y_train)

print(f"Training score: {multi_model.score(X_train, y_train)}")
multi_model_score = multi_model.score(X_test, y_test)
print(f"Test score: {multi_model.score(X_test, y_test)}")
# Out:
# Training score: 0.24598596587258093
# Test score: 0.22715383003265355

# %%
seattle_df.corr()
# Out:
#                    zipcode      id_x  latitude  longitude   price_x      id_y  \
# zipcode           1.000000 -0.576319 -0.232948  -0.450392 -0.315907 -0.031473
# id_x             -0.576319  1.000000  0.282753   0.452531  0.588566 -0.041868
# latitude         -0.232948  0.282753  1.000000   0.054482 -0.012746  0.019561
# longitude        -0.450392  0.452531  0.054482   1.000000  0.008502  0.016270
# price_x          -0.315907  0.588566 -0.012746   0.008502  1.000000 -0.022200
# id_y             -0.031473 -0.041868  0.019561   0.016270 -0.022200  1.000000
# bedrooms         -0.095587  0.096186  0.044537   0.140357  0.066303 -0.002600
# bathrooms        -0.139697  0.088251  0.057639   0.068044  0.167427 -0.016746
# sqft_living      -0.119797  0.117128  0.046331   0.127002  0.192034 -0.019791
# sqft_lot         -0.080407  0.255015  0.045443   0.224445  0.021896 -0.057074
# floors           -0.070646 -0.038201  0.037943  -0.082742  0.148941 -0.009814
# waterfront       -0.007012  0.008530 -0.034075   0.053658  0.001891  0.028325
# sqft_above       -0.158873  0.152158  0.073051   0.149465  0.189225 -0.022893
# sqft_basement     0.009555 -0.005532 -0.020645   0.021456  0.078798 -0.004128
# yr_built         -0.136300  0.175163  0.072611   0.101906  0.028107 -0.036705
# yr_renovated      0.027618 -0.042168 -0.035880  -0.033910  0.037587  0.002374
# lat              -0.226074  0.293438  0.985262   0.066179 -0.008260  0.014979
# long             -0.535130  0.483243  0.087345   0.957249  0.014011  0.019424
# sqft_living15    -0.182473  0.210451  0.076425   0.213547  0.267689 -0.037183
# sqft_lot15       -0.069055  0.297083  0.060844   0.276083  0.019355 -0.053073
# renov_yr_clean   -0.122290  0.151198  0.055928   0.080690  0.045718 -0.032353
# view_ord          0.046989 -0.026521 -0.073605  -0.040606  0.067800  0.011692
# condition_ord    -0.013832 -0.029160  0.045145  -0.017981  0.020630  0.005695
# grade_ord        -0.143494  0.078410  0.102692   0.030409  0.255476 -0.014497
# age               0.136300 -0.175163 -0.072611  -0.101906 -0.028107  0.036705
# airbnb_avg_price -0.130372 -0.012806  0.071613   0.003472  0.267600 -0.013177
#
#                   bedrooms  bathrooms  sqft_living  sqft_lot  ...       lat  \
# zipcode          -0.095587  -0.139697    -0.119797 -0.080407  ... -0.226074
# id_x              0.096186   0.088251     0.117128  0.255015  ...  0.293438
# latitude          0.044537   0.057639     0.046331  0.045443  ...  0.985262
# longitude         0.140357   0.068044     0.127002  0.224445  ...  0.066179
# price_x           0.066303   0.167427     0.192034  0.021896  ... -0.008260
# id_y             -0.002600  -0.016746    -0.019791 -0.057074  ...  0.014979
# bedrooms          1.000000   0.498095     0.594166  0.164451  ...  0.052748
# bathrooms         0.498095   1.000000     0.713849  0.068135  ...  0.063805
# sqft_living       0.594166   0.713849     1.000000  0.289683  ...  0.054138
# sqft_lot          0.164451   0.068135     0.289683  1.000000  ...  0.061278
# floors            0.111948   0.463446     0.240187 -0.223591  ...  0.028686
# waterfront        0.033824   0.086986     0.149267  0.177137  ... -0.031558
# sqft_above        0.500846   0.637718     0.852736  0.270382  ...  0.078600
# sqft_basement     0.379410   0.402878     0.624427  0.143597  ... -0.014099
# yr_built          0.040483   0.413886     0.122555 -0.057304  ...  0.083240
# yr_renovated      0.066465   0.120923     0.134405  0.028311  ... -0.032885
# lat               0.052748   0.063805     0.054138  0.061278  ...  1.000000
# long              0.156200   0.096459     0.154385  0.232091  ...  0.093942
# sqft_living15     0.343009   0.450240     0.676249  0.321899  ...  0.088839
# sqft_lot15        0.165692   0.069238     0.308839  0.669066  ...  0.083570
# renov_yr_clean    0.067682   0.459809     0.173573 -0.056941  ...  0.066954
# view_ord          0.117307   0.239613     0.377754  0.191819  ... -0.066988
# condition_ord     0.102266   0.017903     0.119966  0.045679  ...  0.043204
# grade_ord         0.321130   0.633019     0.695338  0.130333  ...  0.105185
# age              -0.040483  -0.413886    -0.122555  0.057304  ... -0.083240
# airbnb_avg_price  0.331185   0.535845     0.749595  0.203175  ...  0.065906
#
#                       long  sqft_living15  sqft_lot15  renov_yr_clean  \
# zipcode          -0.535130      -0.182473   -0.069055       -0.122290
# id_x              0.483243       0.210451    0.297083        0.151198
# latitude          0.087345       0.076425    0.060844        0.055928
# longitude         0.957249       0.213547    0.276083        0.080690
# price_x           0.014011       0.267689    0.019355        0.045718
# id_y              0.019424      -0.037183   -0.053073       -0.032353
# bedrooms          0.156200       0.343009    0.165692        0.067682
# bathrooms         0.096459       0.450240    0.069238        0.459809
# sqft_living       0.154385       0.676249    0.308839        0.173573
# sqft_lot          0.232091       0.321899    0.669066       -0.056941
# floors           -0.080729       0.089884   -0.278521        0.480974
# waterfront        0.052391       0.161184    0.205076        0.008740
# sqft_above        0.175986       0.600928    0.286062        0.230348
# sqft_basement     0.034711       0.389146    0.154692       -0.009919
# yr_built          0.120677       0.043491   -0.043900        0.898646
# yr_renovated     -0.030966       0.074008    0.032789        0.254979
# lat               0.093942       0.088839    0.083570        0.066954
# long              1.000000       0.248583    0.278830        0.100021
# sqft_living15     0.248583       1.000000    0.407906        0.064694
# sqft_lot15        0.278830       0.407906    1.000000       -0.045642
# renov_yr_clean    0.100021       0.064694   -0.045642        1.000000
# view_ord         -0.035698       0.452702    0.234315        0.019258
# condition_ord    -0.014188       0.105738    0.074817       -0.362124
# grade_ord         0.056966       0.596670    0.142156        0.398866
# age              -0.120677      -0.043491    0.043900       -0.898646
# airbnb_avg_price  0.033899       0.657873    0.205430        0.048912
#
#                   view_ord  condition_ord  grade_ord       age  \
# zipcode           0.046989      -0.013832  -0.143494  0.136300
# id_x             -0.026521      -0.029160   0.078410 -0.175163
# latitude         -0.073605       0.045145   0.102692 -0.072611
# longitude        -0.040606      -0.017981   0.030409 -0.101906
# price_x           0.067800       0.020630   0.255476 -0.028107
# id_y              0.011692       0.005695  -0.014497  0.036705
# bedrooms          0.117307       0.102266   0.321130 -0.040483
# bathrooms         0.239613       0.017903   0.633019 -0.413886
# sqft_living       0.377754       0.119966   0.695338 -0.122555
# sqft_lot          0.191819       0.045679   0.130333  0.057304
# floors            0.052556      -0.160900   0.466529 -0.469213
# waterfront        0.338841       0.008614   0.118013  0.000945
# sqft_above        0.297910       0.016193   0.700918 -0.190227
# sqft_basement     0.270954       0.198683   0.278342  0.046713
# yr_built         -0.012731      -0.327523   0.368124 -1.000000
# yr_renovated      0.094602      -0.083892   0.089041  0.165665
# lat              -0.066988       0.043204   0.105185 -0.083240
# long             -0.035698      -0.014188   0.056966 -0.120677
# sqft_living15     0.452702       0.105738   0.596670 -0.043491
# sqft_lot15        0.234315       0.074817   0.142156  0.043900
# renov_yr_clean    0.019258      -0.362124   0.398866 -0.898646
# view_ord          1.000000       0.041073   0.350518  0.012731
# condition_ord     0.041073       1.000000  -0.018344  0.327523
# grade_ord         0.350518      -0.018344   1.000000 -0.368124
# age               0.012731       0.327523  -0.368124  1.000000
# airbnb_avg_price  0.456273       0.159717   0.708411  0.010801
#
#                   airbnb_avg_price
# zipcode                  -0.130372
# id_x                     -0.012806
# latitude                  0.071613
# longitude                 0.003472
# price_x                   0.267600
# id_y                     -0.013177
# bedrooms                  0.331185
# bathrooms                 0.535845
# sqft_living               0.749595
# sqft_lot                  0.203175
# floors                    0.257486
# waterfront                0.299409
# sqft_above                0.699716
# sqft_basement             0.383032
# yr_built                 -0.010801
# yr_renovated              0.145810
# lat                       0.065906
# long                      0.033899
# sqft_living15             0.657873
# sqft_lot15                0.205430
# renov_yr_clean            0.048912
# view_ord                  0.456273
# condition_ord             0.159717
# grade_ord                 0.708411
# age                       0.010801
# airbnb_avg_price          1.000000
#
# [26 rows x 26 columns]

# %% [markdown]
# Interaction Model

# %%
y = seattle_df['price_x']
X = seattle_df[['bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'sqft_above', 'sqft_basement',
       'yr_built', 'zipcode', 'yr_renovated', 'lat', 'long', 'sqft_living15',
       'sqft_lot15', 'renov_yr_clean', 'view_ord', 'condition_ord',
       'grade_ord', 'age', 'latitude', 'longitude',
       'airbnb_avg_price']]

linear_withinteraction = PolynomialFeatures(degree = 2, interaction_only = True, include_bias = False)


X_transformed = linear_withinteraction.fit_transform(X)
feat_names = pd.Series(linear_withinteraction.get_feature_names())
feat_names
# Out:
# 0           x0
# 1           x1
# 2           x2
# 3           x3
# 4           x4
#         ...
# 271    x19 x21
# 272    x19 x22
# 273    x20 x21
# 274    x20 x22
# 275    x21 x22
# Length: 276, dtype: object

# %%
xs = ['x0', 'x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9', 'x10',  'x11', 'x12', 'x13', 'x14', 'x15','x16','x17','x18','x19','x20','x21', 'x22']

columns = X.columns

map_dict = {x:y for x,y in zip(xs, columns)}

for key, value in map_dict.items():
    feat_names = feat_names.str.replace(key, value)


X_trans_df = pd.DataFrame(X_transformed)
X_trans_df.columns = feat_names

X_trans_df.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  sqft_above  \
# 0       2.0       1.00        770.0   10000.0     1.0         0.0       770.0
# 1       3.0       1.00       1430.0   19901.0     1.5         0.0      1430.0
# 2       4.0       2.25       2590.0   10002.0     1.0         0.0      1340.0
# 3       4.0       2.75       3820.0   26300.0     2.0         0.0      2850.0
# 4       3.0       3.00       2420.0   13959.0     1.0         0.0      1740.0
#
#    sqft_basement  yr_built  zipcode  ...  bathrooms8 bathrooms9  \
# 0            0.0    1933.0  98028.0  ...                  246.0
# 1            0.0    1927.0  98028.0  ...                  352.0
# 2         1250.0    1968.0  98028.0  ...                  235.0
# 3          970.0    2014.0  98028.0  ...                    6.0
# 4          680.0    1988.0  98028.0  ...                  135.0
#
#    bathrooms8 sqft_living0  bathrooms8 sqft_living1  bathrooms8 sqft_living2  \
# 0                143.22033               -366.79551                 540000.0
# 1                190.96044               -489.06068                1240000.0
# 2                238.70055               -611.32585                2260000.0
# 3                286.44066               -733.59102                4620000.0
# 4                238.70055               -611.32585                1650000.0
#
#    bathrooms9 sqft_living0  bathrooms9 sqft_living1  bathrooms9 sqft_living2  \
# 0               3914.68902             -10025.74394               14760000.0
# 1               4201.12968             -10759.33496               27280000.0
# 2               2243.78517              -5746.46299               21244000.0
# 3                 47.74011               -122.26517                 770000.0
# 4               1288.98297              -3301.15959                8910000.0
#
#    sqft_living0 sqft_living1  sqft_living0 sqft_living2  \
# 0               -5836.952665                 8593219.80
# 1               -5836.952665                14799434.10
# 2               -5836.952665                21578529.72
# 3               -5836.952665                36759884.70
# 4               -5836.952665                15754236.30
#
#    sqft_living1 sqft_living2
# 0               -22007730.60
# 1               -37902202.70
# 2               -55263856.84
# 3               -94144180.90
# 4               -40347506.10
#
# [5 rows x 276 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_trans_df, y, test_size=.3, random_state=42
)


# Init, fit, score
stand_model = LinearRegression()
stand_model.fit(X_train, y_train)

print(f"Training score: {stand_model.score(X_train, y_train)}")

print(f"Testing score: {stand_model.score(X_test, y_test)}")

stand_model_score  = stand_model.score(X_test, y_test)
# Out:
# Training score: 0.5158619782077567
# Testing score: 0.4398653871981111

# %% [markdown]
# ## Interaction Model with Distance to Seattle of House

# %%
miles_df = pd.read_excel('/Users/weatherford/Documents/Flatiron/Phase_2_Housing_Project/data/king_county_home_sales.xlsx', index_col=0)

# %%
seattle_df['id'] = seattle_df['id_x']
seattle_df = seattle_df.drop(columns=['id_x'])
seattle_df
# Out:
#       zipcode   latitude   longitude     price_x          id_y        date  \
# 0       98028  47.740110 -122.265170  385.000000  5.631500e+09  2015-02-25
# 1       98028  47.740110 -122.265170  385.000000  1.141015e+08  2014-05-28
# 2       98028  47.740110 -122.265170  385.000000  4.027701e+09  2014-05-29
# 3       98028  47.740110 -122.265170  385.000000  1.126049e+09  2014-11-13
# 4       98028  47.740110 -122.265170  385.000000  5.634500e+09  2015-04-10
# ...       ...        ...         ...         ...           ...         ...
# 9358    98199  47.648094 -122.393581  214.378947  2.770602e+09  2015-04-02
# 9359    98199  47.648094 -122.393581  214.378947  1.070000e+09  2014-10-15
# 9360    98199  47.648094 -122.393581  214.378947  7.010700e+09  2014-11-12
# 9361    98199  47.648094 -122.393581  214.378947  2.770602e+09  2014-08-01
# 9362    98199  47.648094 -122.393581  214.378947  6.821102e+09  2014-09-30
#
#       bedrooms  bathrooms  sqft_living  sqft_lot  ...     long  sqft_living15  \
# 0          2.0       1.00        770.0   10000.0  ... -122.233         2720.0
# 1          3.0       1.00       1430.0   19901.0  ... -122.229         1780.0
# 2          4.0       2.25       2590.0   10002.0  ... -122.266         1550.0
# 3          4.0       2.75       3820.0   26300.0  ... -122.261         1860.0
# 4          3.0       3.00       2420.0   13959.0  ... -122.230         2570.0
# ...        ...        ...          ...       ...  ...      ...            ...
# 9358       3.0       3.25       1550.0    1280.0  ... -122.384         1550.0
# 9359       4.0       3.50       3660.0    4760.0  ... -122.409         3210.0
# 9360       4.0       3.25       3610.0    4000.0  ... -122.396         1980.0
# 9361       3.0       2.50       1510.0    1618.0  ... -122.384         1350.0
# 9362       3.0       2.25       1230.0    1380.0  ... -122.400         1760.0
#
#       sqft_lot15  renov_yr_clean  view_ord  condition_ord  grade_ord   age  \
# 0         8062.0          1933.0       0.0            2.0        3.0  82.0
# 1        12697.0          1927.0       0.0            3.0        4.0  88.0
# 2        10436.0          1968.0       0.0            3.0        5.0  47.0
# 3        12136.0          2014.0       0.0            2.0        6.0   1.0
# 4        13300.0          1988.0       0.0            3.0        5.0  27.0
# ...          ...             ...       ...            ...        ...   ...
# 9358      1579.0          2013.0       0.0            2.0        6.0   2.0
# 9359      4640.0          2014.0       0.0            2.0        6.0   1.0
# 9360      4000.0          2007.0       0.0            2.0        6.0   8.0
# 9361      1397.0          2011.0       0.0            2.0        5.0   4.0
# 9362      5664.0          2013.0       0.0            2.0        5.0   2.0
#
#       airbnb_avg_price            id
# 0             180000.0  5.829030e+17
# 1             310000.0  5.829030e+17
# 2             452000.0  5.829030e+17
# 3             770000.0  5.829030e+17
# 4             330000.0  5.829030e+17
# ...                ...           ...
# 9358          570000.0  6.788531e+16
# 9359         1110000.0  6.788531e+16
# 9360         1010000.0  6.788531e+16
# 9361          453000.0  6.788531e+16
# 9362          549000.0  6.788531e+16
#
# [9356 rows x 27 columns]

# %%
seattle_df.columns
# Out:
# Index(['zipcode', 'latitude', 'longitude', 'price_x', 'id_y', 'date',
#        'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15', 'renov_yr_clean',
#        'view_ord', 'condition_ord', 'grade_ord', 'age', 'airbnb_avg_price',
#        'id'],
#       dtype='object')

# %%
miles_df.columns
# Out:
# Index(['id', 'point', 'distance_to_starbucks_miles',
#        'distance_to_amazon_miles', 'distance_to_needle_miles'],
#       dtype='object')

# %%
miles_df = miles_df.drop(columns=['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'sqft_above', 'sqft_basement',
       'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15',
       'sqft_lot15', 'renovated', 'view_ord', 'condition_ord', 'grade_ord',
       'age'])

# %%
distance_df = pd.merge(seattle_df, miles_df, on='id', how='left')
distance_df.columns
# Out:
# Index(['zipcode', 'latitude', 'longitude', 'price_x', 'id_y', 'date',
#        'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15', 'renov_yr_clean',
#        'view_ord', 'condition_ord', 'grade_ord', 'age', 'airbnb_avg_price',
#        'id', 'point', 'distance_to_starbucks_miles',
#        'distance_to_amazon_miles', 'distance_to_needle_miles'],
#       dtype='object')

# %%
distance_df
# Out:
#       zipcode   latitude   longitude     price_x          id_y        date  \
# 0       98028  47.740110 -122.265170  385.000000  5.631500e+09  2015-02-25
# 1       98028  47.740110 -122.265170  385.000000  1.141015e+08  2014-05-28
# 2       98028  47.740110 -122.265170  385.000000  4.027701e+09  2014-05-29
# 3       98028  47.740110 -122.265170  385.000000  1.126049e+09  2014-11-13
# 4       98028  47.740110 -122.265170  385.000000  5.634500e+09  2015-04-10
# ...       ...        ...         ...         ...           ...         ...
# 9351    98199  47.648094 -122.393581  214.378947  2.770602e+09  2015-04-02
# 9352    98199  47.648094 -122.393581  214.378947  1.070000e+09  2014-10-15
# 9353    98199  47.648094 -122.393581  214.378947  7.010700e+09  2014-11-12
# 9354    98199  47.648094 -122.393581  214.378947  2.770602e+09  2014-08-01
# 9355    98199  47.648094 -122.393581  214.378947  6.821102e+09  2014-09-30
#
#       bedrooms  bathrooms  sqft_living  sqft_lot  ...  view_ord  \
# 0          2.0       1.00        770.0   10000.0  ...       0.0
# 1          3.0       1.00       1430.0   19901.0  ...       0.0
# 2          4.0       2.25       2590.0   10002.0  ...       0.0
# 3          4.0       2.75       3820.0   26300.0  ...       0.0
# 4          3.0       3.00       2420.0   13959.0  ...       0.0
# ...        ...        ...          ...       ...  ...       ...
# 9351       3.0       3.25       1550.0    1280.0  ...       0.0
# 9352       4.0       3.50       3660.0    4760.0  ...       0.0
# 9353       4.0       3.25       3610.0    4000.0  ...       0.0
# 9354       3.0       2.50       1510.0    1618.0  ...       0.0
# 9355       3.0       2.25       1230.0    1380.0  ...       0.0
#
#       condition_ord  grade_ord   age  airbnb_avg_price            id  point  \
# 0               2.0        3.0  82.0          180000.0  5.829030e+17    NaN
# 1               3.0        4.0  88.0          310000.0  5.829030e+17    NaN
# 2               3.0        5.0  47.0          452000.0  5.829030e+17    NaN
# 3               2.0        6.0   1.0          770000.0  5.829030e+17    NaN
# 4               3.0        5.0  27.0          330000.0  5.829030e+17    NaN
# ...             ...        ...   ...               ...           ...    ...
# 9351            2.0        6.0   2.0          570000.0  6.788531e+16    NaN
# 9352            2.0        6.0   1.0         1110000.0  6.788531e+16    NaN
# 9353            2.0        6.0   8.0         1010000.0  6.788531e+16    NaN
# 9354            2.0        5.0   4.0          453000.0  6.788531e+16    NaN
# 9355            2.0        5.0   2.0          549000.0  6.788531e+16    NaN
#
#       distance_to_starbucks_miles  distance_to_amazon_miles  \
# 0                             NaN                       NaN
# 1                             NaN                       NaN
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
# ...                           ...                       ...
# 9351                          NaN                       NaN
# 9352                          NaN                       NaN
# 9353                          NaN                       NaN
# 9354                          NaN                       NaN
# 9355                          NaN                       NaN
#
#       distance_to_needle_miles
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 9351                       NaN
# 9352                       NaN
# 9353                       NaN
# 9354                       NaN
# 9355                       NaN
#
# [9356 rows x 31 columns]

# %%
y = distance_df['price_x']
X = distance_df[['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
       'floors', 'waterfront', 'sqft_above', 'sqft_basement', 'yr_built',
       'zipcode', 'lat', 'long', 'yr_renovated', 'sqft_living15', 'sqft_lot15',
       'renov_yr_clean', 'view_ord', 'condition_ord', 'grade_ord', 'age',
       'latitude', 'longitude', 'airbnb_avg_price', 'distance_to_starbucks_miles',
       'distance_to_amazon_miles', 'distance_to_needle_miles']]

linear_withinteraction = PolynomialFeatures(degree = 2, interaction_only = True, include_bias = False)


X_transformed = linear_withinteraction.fit_transform(X)
feat_names = pd.Series(linear_withinteraction.get_feature_names())
feat_names
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-6d7862259713> in <module>
#      10
#      11
# ---> 12 X_transformed = linear_withinteraction.fit_transform(X)
#      13 feat_names = pd.Series(linear_withinteraction.get_feature_names())
#      14 feat_names
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     688         if y is None:
#     689             # fit method of arity 1 (unsupervised transformation)
# --> 690             return self.fit(X, **fit_params).transform(X)
#     691         else:
#     692             # fit method of arity 2 (supervised transformation)
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/preprocessing/_data.py in fit(self, X, y)
#    1510         self : instance
#    1511         """
# -> 1512         n_samples, n_features = self._validate_data(
#    1513             X, accept_sparse=True).shape
#    1514         combinations = self._combinations(n_features, self.degree,
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     418                     f"requires y to be passed, but the target y is None."
#     419                 )
# --> 420             X = check_array(X, **check_params)
#     421             out = X
#     422         else:
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     642
#     643         if force_all_finite:
# --> 644             _assert_all_finite(array,
#     645                                allow_nan=force_all_finite == 'allow-nan')
#     646
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      94                 not allow_nan and not np.isfinite(X).all()):
#      95             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 96             raise ValueError(
#      97                     msg_err.format
#      98                     (type_err,
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
xs = ['x0', 'x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9', 'x10',  'x11', 'x12', 'x13', 'x14', 'x15','x16','x17','x18','x19','x20','x21', 'x22', 'x23']

columns = X.columns

map_dict = {x:y for x,y in zip(xs, columns)}

for key, value in map_dict.items():
    feat_names = feat_names.str.replace(key, value)


X_trans_df = pd.DataFrame(X_transformed)
X_trans_df.columns = feat_names

X_trans_df.head()

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_trans_df, y, test_size=.3, random_state=42
)


# Init, fit, score
stand_model = LinearRegression()
stand_model.fit(X_train, y_train)

print(f"Training score: {stand_model.score(X_train, y_train)}")

print(f"Testing score: {stand_model.score(X_test, y_test)}")

stand_model_score  = stand_model.score(X_test, y_test)

# %% [markdown]
# Adding the distance to downtown Seattle to the model decreased the R^2 training score slightly and significantly decresed the R^2 testing score.

# %% [markdown]
# ## Model for Whole of King County with Distance to Seattle

# %%
king_dist_df = pd.read_excel('/Users/weatherford/Documents/Flatiron/Phase_2_Housing_Project/data/king_county_home_sales.xlsx', index_col=0)

# %%
king_dist_df.columns

# %%
y = king_dist_df['price']
X = king_dist_df[['bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'sqft_above', 'sqft_basement',
       'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15',
       'sqft_lot15', 'renovated', 'view_ord', 'condition_ord', 'grade_ord',
       'age', 'distance_to_downtown_seattle_miles']]

linear_withinteraction = PolynomialFeatures(degree = 2, interaction_only = True, include_bias = False)


X_transformed = linear_withinteraction.fit_transform(X)
feat_names = pd.Series(linear_withinteraction.get_feature_names())
feat_names

# %%
xs = ['x0', 'x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9', 'x10',  'x11', 'x12', 'x13', 'x14', 'x15','x16','x17','x18','x19','x20','x21']

columns = X.columns

map_dict = {x:y for x,y in zip(xs, columns)}

for key, value in map_dict.items():
    feat_names = feat_names.str.replace(key, value)


X_trans_df = pd.DataFrame(X_transformed)
X_trans_df.columns = feat_names

X_trans_df.head()

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_trans_df, y, test_size=.3, random_state=42
)


# Init, fit, score
stand_model = LinearRegression()
stand_model.fit(X_train, y_train)

print(f"Training score: {stand_model.score(X_train, y_train)}")

print(f"Testing score: {stand_model.score(X_test, y_test)}")

stand_model_score  = stand_model.score(X_test, y_test)

# %% [markdown]
# ## Model to Predict Airbnb price per night by Zipcode by house sale price

# %%
seattle_df.columns

# %%
X, y = seattle_df[['price_x', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
       'floors', 'waterfront', 'sqft_above', 'sqft_basement', 'yr_built',
       'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15',
       'renov_yr_clean', 'view_ord', 'condition_ord', 'grade_ord', 'age',
        'latitude', 'longitude']] , seattle_df[['airbnb_avg_price']]

# Generate train/test sets
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=.3, random_state=42
)

# Init, fit, score
multi_model = LinearRegression()
multi_model.fit(X_train, y_train)

print(f"Training score: {multi_model.score(X_train, y_train)}")
multi_model_score = multi_model.score(X_test, y_test)
print(f"Test score: {multi_model.score(X_test, y_test)}")
