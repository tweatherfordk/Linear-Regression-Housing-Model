# %% [markdown]
# # Exploratory Data Analysis on Categorical Variables
# A deeper dive into waterfront and view

# %%
import itertools
import numpy as np
import pandas as pd 
from numbers import Number
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OrdinalEncoder
# %matplotlib inline

# %%
df = pd.read_csv("/Users/weatherford/Documents/Flatiron/Phase_2_Housing_Project/data/king_county_cleaned.csv")
water_df = df[['waterfront', "price"]]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'date', 'price', 'bedrooms', 'bathrooms',
#        'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'renov_yr_clean', 'view_ord',
#        'condition_ord', 'grade_ord', 'age'],
#       dtype='object')

# %%
water_df.loc[water_df['waterfront'] == 1]
# Out:
#        waterfront      price
# 49              1  1350000.0
# 230             1   655000.0
# 246             1  2400000.0
# 264             1   369900.0
# 300             1  3080000.0
# ...           ...        ...
# 19968           1  1900000.0
# 20309           1  3000000.0
# 20751           1  2300000.0
# 21185           1  2230000.0
# 21560           1  3570000.0
#
# [146 rows x 2 columns]

# %%
g = sns.FacetGrid(df, hue="waterfront", col="view_ord")

g.map(sns.scatterplot, "sqft_living", "price");

# %% [markdown]
# Subset of properties with the best views (view_ord = 4.0) has the greated concentration of waterfront property

# %%
sns.barplot(data=df, x="waterfront", y="price", hue="view_ord");

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
sns.histplot(data=df, x="price", bins=100, hue = 'view_ord');

# %%
b = sns.FacetGrid(df, col="waterfront", height=20, aspect=.35,  hue = "view_ord")
b.map(sns.scatterplot, "sqft_living", "price");
plt.legend(title='View', loc='upper right');

# %%
g = sns.FacetGrid(df, col="view_ord", height=20, aspect=.35)
g.map(sns.histplot, "price");

# %%
sns.scatterplot(data=df, x="waterfront", y="price", hue = "view_ord");

# %% [markdown]
# Subset of properties with the best views (view_ord = 4.0) has the greated concentration of waterfront property

# %%
df['view_ord'].unique()
# Out:
# array([0., 3., 4., 2., 1.])

# %%
df['waterfront'].unique()
# Out:
# array([0, 1])
