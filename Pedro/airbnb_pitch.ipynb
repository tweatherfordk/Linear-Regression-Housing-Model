# %%
import pandas as pd

# %%
profit = pd.read_csv('..\\data\\seattle_income_&_profit.csv', index_col= 'Unnamed: 0')

# %%
profit.columns
# Out:
# Index(['id_x', 'date', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'sqft_above', 'sqft_basement', 'yr_built',
#        'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15',
#        'renov_yr_clean', 'view_ord', 'condition_ord', 'grade_ord', 'age',
#        'id_y', 'latitude', 'longitude', 'airbnb_avg_price', 'house_price',
#        'profit', 'profitable?', '#', 'Location', 'City', 'Population',
#        'Avg. Income/H/hold', 'National Rank'],
#       dtype='object')

# %%
profit.drop(columns = ['date', 'id_x','id_y', 'latitude', 'longitude', '#', 'Location', 'yr_renovated', 'National Rank'], inplace = True)

# %%
profit
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0            3       1.00         1180      5650     1.0           0
# 1            2       1.00          880      6780     1.0           0
# 2            3       2.25         2100      8201     1.0           0
# 3            3       1.00         1300      5898     1.0           0
# 4            2       1.00          860      5265     1.0           0
# ...        ...        ...          ...       ...     ...         ...
# 9351         5       2.50         2170      2752     2.0           0
# 9352         3       2.50         2430      7049     2.0           0
# 9353         3       2.00         1260      1125     2.0           0
# 9354         2       2.50         1590      2656     2.0           0
# 9355         3       2.50         1450      5008     1.0           0
#
#       sqft_above  sqft_basement  yr_built  zipcode  ...  condition_ord  \
# ...

# %%
profit.groupby('City')['profit'].mean().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='City'>
